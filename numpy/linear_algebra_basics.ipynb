# %%
import numpy as np
a = np.matrix([[1, 2, 3],[
              4, 5, 6]])
b = np.matrix([[7, 8],[
              9, 10],[
              11, 12]])
c = np.dot(a, b)
print("Shape",c.shape)
# Out:
# Shape (2, 2)
